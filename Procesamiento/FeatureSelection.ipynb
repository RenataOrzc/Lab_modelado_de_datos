# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://http2.mlstatic.com/D_NQ_NP_2X_960089-MLM26807621582_022018-F.webp" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# #### <font color= #2E9AFE> `Martes y Viernes (Videoconferencia) de 13:00 - 15:00 hrs`</font>
# - <Strong> Maestra: Sara Eugenia Rodríguez </Strong>
# - <Strong> Alumna: Renata Orozco Lopez </Strong>
# - <Strong> Año </Strong>: 2023
# - <Strong> Email: </Strong>  <font color="blue"> `cd682324@iteso.mx` </font>
# ___
#
#
# ### <font color= #2E9AFE> Tema: Selección de Variables</font>

# %% [markdown]
# La selección de variables es un proceso donde automáticamente se seleccionan aquellos atributos en nuestros datos que contribuyen más a la variable a predecir.
#
# Las variables irrelevantes o parcialmente relevantes pueden afectar negativamente el rendimiento del modelo.
#
# Beneficios:
# - Reducir sobreajuste: menos datos irrelevantes significan menos oportunidades de tomar decisiones basadas en ruido = mejor performance.
# - Modelo más fácil de entender
# - Reduce el tiempo de entrenamiento: menos datos significa que el modelo se entrena más rápido
#
#
# **Tipos de algoritmos de selección de variables**
#
#     - **Métodos de envoltura (wrapper)**: se considera como un problema de búsqueda la selección de un conjunto de variables donde diferentes combinaciones se preparan, evalúan y comparan con otras combinaciones. Se utiliza un modelo predictivo para evaluar una combinación de características y asignar un score basado en la precisión del modelo.
#         - Ejemplo: RFE
#
#     - **Métodos de filtrado**: estos métodos aplican una medida estadística para asignar una puntuación a cada característica. Las características se clasifican según la puntuación y se seleccionan para conservarlas o eliminarlas del conjunto de datos. Los métodos suelen ser univariados y consideran la característica de forma independiente o con respecto a la variable dependiente.
#         - Ejemplo: prueba de chi cuadrada, L-Anova, método de correlación, criterio de la varianza
#
#     - **Métodos embebidos (intrinsecos)**: mientras se va creando el modelo el método aprende qué características contribuyen mejor a la precisión. El método más común es el de regularización.
#         - Ejemplo: LASSO, Elastic Net, Ridge, Trees
#
#
# <img src="https://machinelearningmastery.com/wp-content/uploads/2019/11/Overview-of-Feature-Selection-Techniques3.png" width="550" height="480" align="center"/>

# %% [markdown]
# **Mencionando algunas técnicas más comunes:**
#
# - Porcentaje de valores nulos
# - Cantidad de variación
# - Correlación por parejas
# - Mulicolinealidad
# - PCA
# - Correlación con la variable a predecir (target)
# - Forward Selection
# - Backward Selection
# - Stepwise Selection
# - LASSO
# - Selección basada en árboles

# %% [markdown]
# **¿Cómo elegir las mejores variables?**
# No es una respuesta fácil, hay que tratar de varias formas.

# %% [markdown]
# #### Datos: Glass Identification Data Set
# Los datos se pueden encontrar en:
# https://archive.ics.uci.edu/ml/datasets/glass+identification
#
# Se busca identificar qué tipo de vidrio es una muestra.
#
#
# - 1. Id number: 1 a 214
# - 2. RI: Indice Refractivo(medida para saber cuánto se reduce la velocidad de la luz al atravesarlo)
# - 3. Na: Sodio (unidad de medida: porcentaje en peso en el óxido correspondiente, como son los atributos 4-10)
# - 4. Mg: Magenesio
# - 5. Al: Aluminio
# - 6. Si: Silicon
# - 7. K: Potasio
# - 8. Ca: Calcio
# - 9. Ba: Bario
# - 10. Fe: Hierro
# - 11. Tipo de Vidrio:
# -- 1 ventanas de edificios procesadas por flotación
# -- 2 ventanas de edificios no procesadas por flotación
# -- 3 ventanas de vehículos procesadas por flotación
# -- 4 ventanas de vehículos no procesadas por flotación
# -- 5 contenedores
# -- 6 vajilla
# -- 7 faros

# %%
#Importar librerías
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.feature_selection import SelectFromModel
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos del vidrio (variable a predecir categórica)
data = pd.read_csv('glass.data',header=None)
names = ['ID','Indice_Refraccion','Na','Mg','Al','Si','K', 'Ca','Ba','Fe','Tipo_Vidrio']
data.columns = names

# %%
data.head()
# Out:
#    ID  Indice_Refraccion     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0   1            1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1   2            1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2   3            1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3   4            1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4   5            1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Tipo_Vidrio
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %% [markdown]
# # Métodos de Filtrado

# %% [markdown]
# ## Métodos de eliminación sólo variables predictoras (X)

# %% [markdown]
# ### Eliminar variable con % de datos nulos
#
# Cuando hay muchos datos nulos, es difícil para el algoritmo aprender de esos datos (ya que no hay nada)
#
# Hay 2 opciones:
# 1. Quitar variables que tienen un % alto de datos nulos
#
#    (\# de datos con valores nulos/ \# total de datos)
#
#
# 2. Crear indicadores binarios que explícitamente digan existente / valor nulo

# %% [markdown]
# ### Criterio de la correlación entre pares (sin tomar en cuenta la variable target "Y")
#
# $$y=\beta_{0}+\beta_{1}X_{1}+\beta_{2}X_{2}+...+\epsilon$$
#
# Cuando existe correlación entre 2 variables predictoras "X", no podemos determinar el efecto de una 1 variable tomando en cuenta que la otra variable es constante ya que las dos variables cambian juntas.
#
# Cuando se tienen variables relacionadas, se puede considerar que todas las variables proporcionan la misma información al modelo. Por lo que, es deseable seleccionar solo variables que no estén relacionadas y evitar redundancia de información.
#
# Si dos variables están altamente correlacionadas, dejar sólo una va a ayudar a reducir la dimensionalidad sin perder mucha información.
#
# La matriz de correlaciones puede ayudar a visualizar si existen variables candidatas a ser descartadas. Un buen Threshold para eliminar variables, es quitar todas aquellas cuya correlación > 0.6

# %%
#Separar X de Y
X = data.iloc[:,1:10]
Y = data.iloc[:,10]

co= X.corr()
co.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/2x/ywqv7yz10h9cq_ql_b4l1vpw0000gn/T/ipykernel_88445/3720957934.py:6: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   co.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_ba936_row0_col0, #T_ba936_row1_col1, #T_ba936_row2_col2, #T_ba936_row3_col3, #T_ba936_row4_col4, #T_ba936_row5_col5, #T_ba936_row6_col6, #T_ba936_row7_col7, #T_ba936_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ba936_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ba936_row0_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_ba936_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ba936_row0_col4, #T_ba936_row1_col8, #T_ba936_row2_col1, #T_ba936_row2_col3, #T_ba936_row2_col6, #T_ba936_row2_col7, #T_ba936_row4_col0, #T_ba936_row6_col1, #T_ba936_row6_col5, #T_ba936_row7_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ba936_row0_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ba936_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_ba936_row0_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_ba936_row0_col8 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_ba936_row1_col0, #T_ba936_row7_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_ba936_row1_col2, #T_ba936_row7_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ba936_row1_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_ba936_row1_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_ba936_row1_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ba936_row1_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ba936_row1_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_ba936_row2_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ba936_row2_col4, #T_ba936_row2_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_ba936_row2_col8, #T_ba936_row4_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_ba936_row3_col0, #T_ba936_row5_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ba936_row3_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ba936_row3_col2, #T_ba936_row5_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_ba936_row3_col4, #T_ba936_row7_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ba936_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_ba936_row3_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ba936_row3_col7, #T_ba936_row7_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_ba936_row3_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ba936_row4_col1, #T_ba936_row4_col6, #T_ba936_row5_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_ba936_row4_col2, #T_ba936_row6_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ba936_row4_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_ba936_row4_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ba936_row4_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_ba936_row5_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_ba936_row5_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_ba936_row5_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_ba936_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ba936_row5_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ba936_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_ba936_row6_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ba936_row6_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_ba936_row6_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ba936_row6_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ba936_row7_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_ba936_row7_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ba936_row7_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_ba936_row8_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_ba936_row8_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ba936_row8_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_ba936_row8_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_ba936_row8_col4, #T_ba936_row8_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ba936_row8_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ba936_row8_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# </style>
# <table id="T_ba936">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba936_level0_col0" class="col_heading level0 col0" >Indice_Refraccion</th>
#       <th id="T_ba936_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_ba936_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_ba936_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_ba936_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_ba936_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_ba936_level0_col6" class="col_heading level0 col6" >Ca</th>
#       <th id="T_ba936_level0_col7" class="col_heading level0 col7" >Ba</th>
#       <th id="T_ba936_level0_col8" class="col_heading level0 col8" >Fe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba936_level0_row0" class="row_heading level0 row0" >Indice_Refraccion</th>
#       <td id="T_ba936_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_ba936_row0_col1" class="data row0 col1" >-0.19</td>
#       <td id="T_ba936_row0_col2" class="data row0 col2" >-0.12</td>
#       <td id="T_ba936_row0_col3" class="data row0 col3" >-0.41</td>
#       <td id="T_ba936_row0_col4" class="data row0 col4" >-0.54</td>
#       <td id="T_ba936_row0_col5" class="data row0 col5" >-0.29</td>
#       <td id="T_ba936_row0_col6" class="data row0 col6" >0.81</td>
#       <td id="T_ba936_row0_col7" class="data row0 col7" >-0.00</td>
#       <td id="T_ba936_row0_col8" class="data row0 col8" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_ba936_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_ba936_row1_col0" class="data row1 col0" >-0.19</td>
#       <td id="T_ba936_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_ba936_row1_col2" class="data row1 col2" >-0.27</td>
#       <td id="T_ba936_row1_col3" class="data row1 col3" >0.16</td>
#       <td id="T_ba936_row1_col4" class="data row1 col4" >-0.07</td>
#       <td id="T_ba936_row1_col5" class="data row1 col5" >-0.27</td>
#       <td id="T_ba936_row1_col6" class="data row1 col6" >-0.28</td>
#       <td id="T_ba936_row1_col7" class="data row1 col7" >0.33</td>
#       <td id="T_ba936_row1_col8" class="data row1 col8" >-0.24</td>
#     </tr>
#     <tr>
#       <th id="T_ba936_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_ba936_row2_col0" class="data row2 col0" >-0.12</td>
#       <td id="T_ba936_row2_col1" class="data row2 col1" >-0.27</td>
#       <td id="T_ba936_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_ba936_row2_col3" class="data row2 col3" >-0.48</td>
#       <td id="T_ba936_row2_col4" class="data row2 col4" >-0.17</td>
#       <td id="T_ba936_row2_col5" class="data row2 col5" >0.01</td>
#       <td id="T_ba936_row2_col6" class="data row2 col6" >-0.44</td>
#       <td id="T_ba936_row2_col7" class="data row2 col7" >-0.49</td>
#       <td id="T_ba936_row2_col8" class="data row2 col8" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_ba936_level0_row3" class="row_heading level0 row3" >Al</th>
#       <td id="T_ba936_row3_col0" class="data row3 col0" >-0.41</td>
#       <td id="T_ba936_row3_col1" class="data row3 col1" >0.16</td>
#       <td id="T_ba936_row3_col2" class="data row3 col2" >-0.48</td>
#       <td id="T_ba936_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_ba936_row3_col4" class="data row3 col4" >-0.01</td>
#       <td id="T_ba936_row3_col5" class="data row3 col5" >0.33</td>
#       <td id="T_ba936_row3_col6" class="data row3 col6" >-0.26</td>
#       <td id="T_ba936_row3_col7" class="data row3 col7" >0.48</td>
#       <td id="T_ba936_row3_col8" class="data row3 col8" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_ba936_level0_row4" class="row_heading level0 row4" >Si</th>
#       <td id="T_ba9

# %%
def calcDrop(res):
    # Obtener todas las variables con una correlacion  > 0.6
    all_corr_vars = list(set(res['v1'].tolist() + res['v2'].tolist()))
    
    # Todas las variables únicas en las columnas a remover
    poss_drop = list(set(res['drop'].tolist()))

    # Quedarse con las variables que no estén en las variables a remover
    keep = list(set(all_corr_vars).difference(set(poss_drop)))
     
    p = res[ res['v1'].isin(keep)  | res['v2'].isin(keep) ][['v1', 'v2']]
    q = list(set(p['v1'].tolist() + p['v2'].tolist()))
    drop = (list(set(q).difference(set(keep))))

    poss_drop = list(set(poss_drop).difference(set(drop)))
    
    m = res[ res['v1'].isin(poss_drop)  | res['v2'].isin(poss_drop) ][['v1', 'v2','drop']]
        
    more_drop = set(list(m[~m['v1'].isin(drop) & ~m['v2'].isin(drop)]['drop']))
    for item in more_drop:
        drop.append(item)
         
    return drop


def corrX_new(df, cut = 0.6) :
       
    corr_mtx = df.corr().abs()
    avg_corr = corr_mtx.mean(axis = 1)
    up = corr_mtx.where(np.triu(np.ones(corr_mtx.shape), k=1).astype(np.bool))
    
    dropcols = list()
    
    res = pd.DataFrame(columns=(['v1', 'v2', 'v1.target', 
                                 'v2.target','corr', 'drop' ]))
    
    for row in range(len(up)-1):
        col_idx = row + 1
        for col in range (col_idx, len(up)):
            if(corr_mtx.iloc[row, col] > cut):
                if(avg_corr.iloc[row] > avg_corr.iloc[col]): 
                    dropcols.append(row)
                    drop = corr_mtx.columns[row]
                else: 
                    dropcols.append(col)
                    drop = corr_mtx.columns[col]
                
                s = pd.Series([ corr_mtx.index[row],
                up.columns[col],
                avg_corr[row],
                avg_corr[col],
                up.iloc[row,col],
                drop],
                index = res.columns)
        
                res = res.append(s, ignore_index = True)
    
    dropcols_names = calcDrop(res)
    
    return(dropcols_names)

drop = corrX_new(X)
print(drop)

# %% [markdown]
# La única variable a remover es la del calcio.

# %%
X_no_corr = X.drop(columns=['Ca'], axis=1)

# %%
co= X_no_corr.corr()
co.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/2x/ywqv7yz10h9cq_ql_b4l1vpw0000gn/T/ipykernel_88445/1633193344.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   co.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_4c6d1_row0_col0, #T_4c6d1_row1_col1, #T_4c6d1_row2_col2, #T_4c6d1_row3_col3, #T_4c6d1_row4_col4, #T_4c6d1_row5_col5, #T_4c6d1_row6_col6, #T_4c6d1_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4c6d1_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_4c6d1_row0_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_4c6d1_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_4c6d1_row0_col4, #T_4c6d1_row0_col5, #T_4c6d1_row1_col7, #T_4c6d1_row2_col1, #T_4c6d1_row2_col3, #T_4c6d1_row2_col6, #T_4c6d1_row4_col0, #T_4c6d1_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4c6d1_row0_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_4c6d1_row0_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_4c6d1_row1_col0, #T_4c6d1_row2_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_4c6d1_row1_col2, #T_4c6d1_row6_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_4c6d1_row1_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_4c6d1_row1_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_4c6d1_row1_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_4c6d1_row1_col6 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_4c6d1_row2_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_4c6d1_row2_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_4c6d1_row2_col7, #T_4c6d1_row4_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_4c6d1_row3_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_4c6d1_row3_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_4c6d1_row3_col2, #T_4c6d1_row5_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_4c6d1_row3_col4, #T_4c6d1_row6_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_4c6d1_row3_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_4c6d1_row3_col6, #T_4c6d1_row6_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_4c6d1_row3_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_4c6d1_row4_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_4c6d1_row4_col2, #T_4c6d1_row7_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_4c6d1_row4_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_4c6d1_row4_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_4c6d1_row4_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_4c6d1_row5_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_4c6d1_row5_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_4c6d1_row5_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_4c6d1_row5_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_4c6d1_row5_col6 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_4c6d1_row5_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_4c6d1_row6_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_4c6d1_row6_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_4c6d1_row6_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_4c6d1_row7_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_4c6d1_row7_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_4c6d1_row7_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_4c6d1_row7_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_4c6d1_row7_col4, #T_4c6d1_row7_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# </style>
# <table id="T_4c6d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c6d1_level0_col0" class="col_heading level0 col0" >Indice_Refraccion</th>
#       <th id="T_4c6d1_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_4c6d1_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_4c6d1_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_4c6d1_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_4c6d1_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_4c6d1_level0_col6" class="col_heading level0 col6" >Ba</th>
#       <th id="T_4c6d1_level0_col7" class="col_heading level0 col7" >Fe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c6d1_level0_row0" class="row_heading level0 row0" >Indice_Refraccion</th>
#       <td id="T_4c6d1_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_4c6d1_row0_col1" class="data row0 col1" >-0.19</td>
#       <td id="T_4c6d1_row0_col2" class="data row0 col2" >-0.12</td>
#       <td id="T_4c6d1_row0_col3" class="data row0 col3" >-0.41</td>
#       <td id="T_4c6d1_row0_col4" class="data row0 col4" >-0.54</td>
#       <td id="T_4c6d1_row0_col5" class="data row0 col5" >-0.29</td>
#       <td id="T_4c6d1_row0_col6" class="data row0 col6" >-0.00</td>
#       <td id="T_4c6d1_row0_col7" class="data row0 col7" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_4c6d1_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_4c6d1_row1_col0" class="data row1 col0" >-0.19</td>
#       <td id="T_4c6d1_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_4c6d1_row1_col2" class="data row1 col2" >-0.27</td>
#       <td id="T_4c6d1_row1_col3" class="data row1 col3" >0.16</td>
#       <td id="T_4c6d1_row1_col4" class="data row1 col4" >-0.07</td>
#       <td id="T_4c6d1_row1_col5" class="data row1 col5" >-0.27</td>
#       <td id="T_4c6d1_row1_col6" class="data row1 col6" >0.33</td>
#       <td id="T_4c6d1_row1_col7" class="data row1 col7" >-0.24</td>
#     </tr>
#     <tr>
#       <th id="T_4c6d1_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_4c6d1_row2_col0" class="data row2 col0" >-0.12</td>
#       <td id="T_4c6d1_row2_col1" class="data row2 col1" >-0.27</td>
#       <td id="T_4c6d1_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_4c6d1_row2_col3" class="data row2 col3" >-0.48</td>
#       <td id="T_4c6d1_row2_col4" class="data row2 col4" >-0.17</td>
#       <td id="T_4c6d1_row2_col5" class="data row2 col5" >0.01</td>
#       <td id="T_4c6d1_row2_col6" class="data row2 col6" >-0.49</td>
#       <td id="T_4c6d1_row2_col7" class="data row2 col7" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_4c6d1_level0_row3" class="row_heading level0 row3" >Al</th>
#       <td id="T_4c6d1_row3_col0" class="data row3 col0" >-0.41</td>
#       <td id="T_4c6d1_row3_col1" class="data row3 col1" >0.16</td>
#       <td id="T_4c6d1_row3_col2" class="data row3 col2" >-0.48</td>
#       <td id="T_4c6d1_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_4c6d1_row3_col4" class="data row3 col4" >-0.01</td>
#       <td id="T_4c6d1_row3_col5" class="data row3 col5" >0.33</td>
#       <td id="T_4c6d1_row3_col6" class="data row3 col6" >0.48</td>
#       <td id="T_4c6d1_row3_col7" class="data row3 col7" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_4c6d1_level0_row4" class="row_heading level0 row4" >Si</th>
#       <td id="T_4c6d1_row4_col0" class="data row4 col0" >-0.54</td>
#       <td id="T_4c6d1_row4_col1" class="data row4 col1" >-0.07</td>
#       <td id="T_4c6d1_row4_col2" class="data row4 col2" >-0.17</td>
#       <td id="T_4c6d1_row4_col3" class="data row4 col3" >-0.01</td>
#       <td id="T_4c6d1_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_4c6d1_row4_col5" class="data row4 col5" >-0.19</td>
#       <td id="T_4c6d1_row4_col6" class="data row4 col6" >-0.10</td>
#       <td id="T_4c6d1_row4_col7" class="data row4 col7" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_4c6d1_level0_row5" class="row_heading level0 row5" >K</th>
#       <td id="T_4c6d1_row5_col0" class="data row5 col0" >-0.29</td>
#       <td id="T_4c6d1_row5_col1" class="data row5 col1" >-0.27</td>
#       <td id="T_4c6d1_row5_col2" class="data row5 col2" >0.01</td>
#       <td id="T_4c6d1_row5_col3" class="data row5 col3" >0.33</td>
#       <td id="T_4c6d1_row5_col4" class="data row5 col4" >-0.19</td>
#       <td id="T_4c6d1_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_4c6d1_row5_col6" class="data row5 col6" >-0.04</td>
#       <td id="T_4c6d1_row5_col7" class="data row5 col7" >-0.01</td>
#     </tr>
#     <tr>
#       <th

# %% [markdown]
# Ya no existen variables X altamente correlacionadas

# %% [markdown]
# ## Métodos de eliminación tomando en cuenta X y Y

# %% [markdown]
# ### Criterio de la correlación contra la variable target "Y"
#
# - Eliminar variables que tienen una correlación baja con la variable a predecir
#
# - Si una variable tiene baja correlación con el target, no va a ser útil para la predicción

# %%
co= data.iloc[:,1:11].corr()
co.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/2x/ywqv7yz10h9cq_ql_b4l1vpw0000gn/T/ipykernel_88445/1855992814.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   co.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_5601a_row0_col0, #T_5601a_row1_col1, #T_5601a_row2_col2, #T_5601a_row3_col3, #T_5601a_row4_col4, #T_5601a_row5_col5, #T_5601a_row6_col6, #T_5601a_row7_col7, #T_5601a_row8_col8, #T_5601a_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5601a_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_5601a_row0_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_5601a_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_5601a_row0_col4, #T_5601a_row1_col8, #T_5601a_row2_col1, #T_5601a_row2_col3, #T_5601a_row2_col6, #T_5601a_row2_col7, #T_5601a_row2_col9, #T_5601a_row4_col0, #T_5601a_row6_col1, #T_5601a_row6_col5, #T_5601a_row9_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5601a_row0_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_5601a_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_5601a_row0_col7, #T_5601a_row4_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_5601a_row0_col8 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_5601a_row0_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_5601a_row1_col0, #T_5601a_row7_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5601a_row1_col2, #T_5601a_row2_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_5601a_row1_col3, #T_5601a_row5_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_5601a_row1_col4, #T_5601a_row9_col6 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_5601a_row1_col5, #T_5601a_row9_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_5601a_row1_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_5601a_row1_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_5601a_row1_col9, #T_5601a_row9_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_5601a_row2_col4, #T_5601a_row2_col5, #T_5601a_row9_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_5601a_row2_col8, #T_5601a_row4_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_5601a_row3_col0, #T_5601a_row5_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_5601a_row3_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_5601a_row3_col2, #T_5601a_row6_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_5601a_row3_col4, #T_5601a_row7_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_5601a_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_5601a_row3_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_5601a_row3_col7, #T_5601a_row7_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_5601a_row3_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_5601a_row3_col9 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_5601a_row4_col1, #T_5601a_row4_col6, #T_5601a_row5_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_5601a_row4_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_5601a_row4_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_5601a_row4_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_5601a_row4_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_5601a_row5_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_5601a_row5_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_5601a_row5_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_5601a_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_5601a_row5_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_5601a_row5_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_5601a_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_5601a_row6_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_5601a_row6_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_5601a_row6_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_5601a_row6_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_5601a_row6_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_5601a_row7_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_5601a_row7_col2, #T_5601a_row7_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_5601a_row7_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_5601a_row7_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_5601a_row7_col9 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_5601a_row8_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_5601a_row8_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_5601a_row8_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_5601a_row8_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_5601a_row8_col4, #T_5601a_row8_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_5601a_row8_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_5601a_row8_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_5601a_row8_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_5601a_row9_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_5601a_row9_col3 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_5601a_row9_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_5601a_row9_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5601a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5601a_level0_col0" class="col_heading level0 col0" >Indice_Refraccion</th>
#       <th id="T_5601a_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_5601a_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_5601a_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_5601a_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_5601a_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_5601a_level0_col6" class="col_heading level0 col6" >Ca</th>
#       <th id="T_5601a_level0_col7" class="col_heading level0 col7" >Ba</th>
#       <th id="T_5601a_level0_col8" class="col_heading level0 col8" >Fe</th>
#       <th id="T_5601a_level0_col9" class="col_heading level0 col9" >Tipo_Vidrio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5601a_level0_row0" class="row_heading level0 row0" >Indice_Refraccion</th>
#       <td id="T_5601a_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_5601a_row0_col1" class="data row0 col1" >-0.19</td>
#       <td id="T_5601a_row0_col2" class="data row0 col2" >-0.12</td>
#       <td id="T_5601a_row0_col3" class="data row0 col3" >-0.41</td>
#       <td id="T_5601a_row0_col4" class="data row0 col4" >-0.54</td>
#       <td id="T_5601a_row0_col5" class="data row0 col5" >-0.29</td>
#       <td id="T_5601a_row0_col6" class="data row0 col6" >0.81</td>
#       <td id="T_5601a_row0_col7" class="data row0 col7" >-0.00</td>
#       <td id="T_5601a_row0_col8" class="data row0 col8" >0.14</td>
#       <td id="T_5601a_row0_col9" class="data row0 col9" >-0.16</td>
#     </tr>
#     <tr>
#       <th id="T_5601a_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_5601a_row1_col0" class="data row1 col0" >-0.19</td>
#       <td id="T_5601a_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_5601a_row1_col2" class="data row1 col2" >-0.27</td>
#       <td id="T_5601a_row1_col3" class="data row1 col3" >0.16</td>
#       <td id="T_5601a_row1_col4" class="data row1 col4" >-0.07</td>
#       <td id="T_5601a_row1_col5" class="data row1 col5" >-0.27</td>
#       <td id="T_5601a_row1_col6" class="data row1 col6" >-0.28</td>
#       <td id="T_5601a_row1_col7" class="data row1 col7" >0.33</td>
#       <td id="T_5601a_row1_col8" class="data row1 col8" >-0.24</td>
#       <td id="T_5601a_row1_col9" class="data row1 col9" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_5601a_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_5601a_row2_col0" class="data row2 col0" >-0.12</td>
#       <td id="T_5601a_row2_col1" class="data row2 col1" >-0.27</td>
#       <td id="T_5601a_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_5601a_row2_col3" class="data row2 col3" >-0.48</td>

# %% [markdown]
# Conclusión:

# %% [markdown]
# # Métodos de Envoltura

# %% [markdown]
# ### Eliminación Recursiva de Características (RFE)
#
# Funciona eliminando atributos de forma recursiva y construyendo un modelo sobre los atributos que quedan.
#
# Usa la precisión del modelo para identificar qué atributos (y combinación de atributos) contribuyen más a predecir el objetivo.
#
# Vamos a utilizar la regresión logística para seleccionar las 4 características principales. La elección del algoritmo no importa demasiado siempre que sea hábil y consistente con el tipo de problema.

# %%
#RFE
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
#crear modelo de regresión logística
model = LogisticRegression()
#crear el recursive feature elimination para la regresión logística, seleccionando sólo 4 variables
rfe = RFE(model)
#ajusta modelo
fit = rfe.fit(X, Y)
print("# de características: %d" % fit.n_features_)
print("Características seleccionadas: %s" % fit.support_)

#true = variable que vamos a 
#False, variable que no funciona en el modelo
# Out:
# # de características: 4
# Características seleccionadas: [False False  True  True False  True False  True False]
# /Users/renataorozcolopez/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/renataorozcolopez/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/renataorozcolopez/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/renataorozcolopez/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/renataorozcolopez/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/renataorozcolopez/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
data.head()
# Out:
#    ID  Indice_Refraccion     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0   1            1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1   2            1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2   3            1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3   4            1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4   5            1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Tipo_Vidrio
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
X.loc[:, fit.support_]
# Out:
#        Mg    Al     K    Ba
# 0    4.49  1.10  0.06  0.00
# 1    3.60  1.36  0.48  0.00
# 2    3.55  1.54  0.39  0.00
# 3    3.69  1.29  0.57  0.00
# 4    3.62  1.24  0.55  0.00
# ..    ...   ...   ...   ...
# 209  0.00  2.88  0.08  1.06
# 210  0.00  1.99  0.00  1.59
# 211  0.00  2.02  0.00  1.64
# 212  0.00  1.94  0.00  1.57
# 213  0.00  2.08  0.00  1.67
#
# [214 rows x 4 columns]

# %% [markdown]
# El RFE eligió las siguientes variables: Mg, Al, K, Ba
# Están marcadas como "True".
# De igual manera, los resultados pueden variar dependiendo de la naturaleza estocástica del algoritmo o el proceso de evaluación, o diferencias en la precisión numérica. Se recomienda correr el ejercicio varias veces para comparar el resultado promedio.

# %% [markdown]
# # Métodos embebidos (intrínsecos)

# %% [markdown]
# ### Selección de variables basada en árboles
#
# Modelos basados en árboles como el "Random Forest" ya tienen dentro de su proceso un método de seleción de variables donde estiman la importancia de los atributos.
#
# Construimos un Clasificador de "Random Forest"

# %%
# Importancia de las variables con clasificador de Random Forest
from sklearn.ensemble import RandomForestClassifier
# crear objeto de Random Forest
model = RandomForestClassifier()
#Ajustar modelo a datos
model.fit(X, Y)

importances = pd.DataFrame(data={
    'Attribute':data.iloc[:,1:10].columns, 
    'Importance': model.feature_importances_
})
importances = importances.sort_values(by='Importance', ascending=False)
importances
# Out:
#            Attribute  Importance
# 2                 Mg    0.156534
# 3                 Al    0.145405
# 0  Indice_Refraccion    0.144806
# 6                 Ca    0.123374
# 1                 Na    0.111376
# 7                 Ba    0.104707
# 4                 Si    0.089276
# 5                  K    0.087232
# 8                 Fe    0.037290

# %% [markdown]
# Las 4 variables más importantes serían: Mg, Al, Ca e Indice de Refraccion

# %%
plt.bar(x=importances['Attribute'], height=importances['Importance'], color='#087E8B')
plt.title('Importancia de los atributos obtenido de los coeficientes', size=15)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Regularización Least Absolute Shrinkage and Selection Operator (LASSO)
#
# Lo que hace LASSO es que tiene un parámetro de regularización que penaliza a algunas variables y las hace cero.

# %%
#Separar en datos de entrenamiento y de prueba
X= data.drop(labels=['ID', 'Tipo_Vidrio'], axis=1)
Y= data['Tipo_Vidrio']

# %%
data.head()
# Out:
#    ID  Indice_Refraccion     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0   1            1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1   2            1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2   3            1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3   4            1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4   5            1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Tipo_Vidrio
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %% [markdown]
# La mayoría de los modelos lineales se benefician de escalar los datos.

# %%
#Escalar datos de entrenamiento
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
##LASSO
from sklearn.feature_selection import SelectFromModel
sel=LogisticRegression(C=1, penalty='l1', solver='liblinear').fit(X,Y) #LASSO  = L1
sel=SelectFromModel(sel, prefit=True) #seleccion de variable
X_new=sel.transform(X)
X_new.shape
# Out:
# /Users/renataorozcolopez/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/renataorozcolopez/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# (214, 8)

# %%
pd.DataFrame(X_new)
# Out:
#          0     1     2      3     4     5     6    7
# 0    13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..     ...   ...   ...    ...   ...   ...   ...  ...
# 209  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 8 columns]

# %%
X.head()
# Out:
#    Indice_Refraccion     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0            1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1            1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2            1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3            1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4            1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0

# %% [markdown]
# El modelo quitó la variable "Indice de Refracción"

# %% [markdown]
# ### ¿Cuál es el mejor método?
#
# ...no hay...
#
# Se tiene que hacer experimentación para ver qué método funciona mejor para el problema en específico.

# %% [markdown]
# ### Referencias:
#
# - Comparison of F-test and mutual information: https://scikit-learn.org/stable/auto_examples/feature_selection/plot_f_test_vs_mi.html#sphx-glr-auto-examples-feature-selection-plot-f-test-vs-mi-py
# - Feature selection: https://scikit-learn.org/stable/modules/feature_selection.html

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Sara E. Rodríguez.
# </footer>
